# %% [markdown]
# # <u>NOTEBOOK JUAN JOSÉ ANÁLISIS EXPLORATORIO (Manufacturer to Drivetrain)</u>

# %%
import pandas as pd

# %%
df_juanjose = pd.read_csv('../data/cars.csv')

# %%
df_juanjose
# Out:
#        manufacturer            model  year   mileage  \
# 0             Acura  ILX Hybrid 1.5L  2013   92945.0
# 1             Acura  ILX Hybrid 1.5L  2013   47645.0
# 2             Acura  ILX Hybrid 1.5L  2013   53422.0
# 3             Acura  ILX Hybrid 1.5L  2013  117598.0
# 4             Acura  ILX Hybrid 1.5L  2013  114865.0
# ...             ...              ...   ...       ...
# 762086        Volvo  S60 B5 Momentum  2022   22877.0
# 762087        Volvo           S60 T5  2012   72900.0
# 762088        Volvo           S60 T5  2014   92000.0
# 762089        Volvo  S60 T5 Platinum  2013  132000.0
# 762090        Volvo   S60 T5 Premier  2015  115592.0
#
#                                                    engine       transmission  \
# 0       1.5L I-4 i-VTEC variable valve control, engine...          Automatic
# 1                             1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# 2                             1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# ...

# %%
df_juanjose.columns
# Out:
# Index(['manufacturer', 'model', 'year', 'mileage', 'engine', 'transmission',
#        'drivetrain', 'fuel_type', 'mpg', 'exterior_color', 'interior_color',
#        'accidents_or_damage', 'one_owner', 'personal_use_only', 'seller_name',
#        'seller_rating', 'driver_rating', 'driver_reviews_num', 'price_drop',
#        'price'],
#       dtype='object')

# %%
columns = ['manufacturer', 'model', 'year', 'mileage', 'engine', 'transmission', 'drivetrain']
df = df_juanjose[columns].copy()

# %% [markdown]
# ### <u>'manufacturer'</u>

# %%
df_juanjose['manufacturer'].value_counts()
# Out:
# manufacturer
# Ford             79526
# Toyota           59535
# Chevrolet        56043
# Nissan           48529
# Jeep             41665
# Mercedes-Benz    40824
# Honda            37612
# BMW              37570
# Kia              35063
# GMC              29563
# Dodge            25250
# Subaru           24767
# Volkswagen       24620
# Hyundai          22203
# Lexus            21301
# RAM              19364
# Audi             17863
# Cadillac         17794
# Mazda            15485
# Buick            14624
# Chrysler         12647
# INFINITI         12289
# Land Rover       12272
# Porsche          11461
# Lincoln          10608
# Volvo            10029
# Acura             8489
# Tesla             5883
# Mitsubishi        5743
# Jaguar            3469
# Name: count, dtype: int64

# %%
df_juanjose['manufacturer'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### No tenemos ningún missing.

# %% [markdown]
# ### <u>'model'</u>

# %%
df_juanjose['model'].value_counts()
# Out:
# model
# Fusion SE                     3172
# Sportage LX                   2873
# Corolla LE                    2836
# GLC 300 Base 4MATIC           2718
# Sentra SV                     2652
#                               ...
# E-Class Coupe //AMG Sport        1
# E-Class E 400 Cabriolet 2D       1
# 400 Base                         1
# E-Class 3.0                      1
# S60 T5 Drive-E Platinum          1
# Name: count, Length: 12187, dtype: int64

# %%
df_juanjose['model'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### No tenemos ningún missing.

# %% [markdown]
# ### <u>'year'</u>

# %%
df_juanjose['year'].unique
# Out:
# <bound method Series.unique of 0         2013
# 1         2013
# 2         2013
# 3         2013
# 4         2013
#           ...
# 762086    2022
# 762087    2012
# 762088    2014
# 762089    2013
# 762090    2015
# Name: year, Length: 762091, dtype: int64>

# %%
df_juanjose['year'].min()
# Out:
# 1915

# %%
df_juanjose['year'].max()
# Out:
# 2024

# %%
df_juanjose['year'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### No hay ningún missing y el valor mínimo es coherente. Mantendremos todos los valores.

# %% [markdown]
# ### <u>'mileage'</u>

# %%
df_juanjose['mileage'].isna().sum()
# Out:
# np.int64(506)

# %% [markdown]
# ##### Son muy pocos missing, ya veremos como los rellenamos.

# %% [markdown]
# ### <u>'engine'</u>

# %%
df_juanjose['engine'].nunique()
# Out:
# 6903

# %%
df_juanjose['engine'].isna().sum()
# Out:
# np.int64(15050)

# %% [markdown]
# ##### Son pocos missing, podemos rellenarlos.

# %% [markdown]
# ### <u>'transmission'</u>

# %%
df_juanjose['transmission'].nunique()
# Out:
# 1313

# %%
df_juanjose['transmission'].isna().sum()
# Out:
# np.int64(9904)

# %% [markdown]
# ### <u>'drivetrain'</u>

# %%
df_juanjose['drivetrain'].isna().sum()
# Out:
# np.int64(21562)

# %% [markdown]
# ##### Son pocos missing, podemos rellenarlos.
