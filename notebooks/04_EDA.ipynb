# %% [markdown]
# # <u>LIMPIEZA DEL DATASET:</u>

# %%
import numpy as np
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
df = pd.read_csv('../data/raw/cars.csv')

# %% [markdown]
# ## <u>1. NORMALIZACIÓN DE DATOS:</u>

# %%
df.dtypes
# Out:
# manufacturer            object
# model                   object
# year                     int64
# mileage                float64
# engine                  object
# transmission            object
# drivetrain              object
# fuel_type               object
# mpg                     object
# exterior_color          object
# interior_color          object
# accidents_or_damage    float64
# one_owner              float64
# personal_use_only      float64
# seller_name             object
# seller_rating          float64
# driver_rating          float64
# driver_reviews_num     float64
# price_drop             float64
# price                  float64
# dtype: object

# %%
df.dtypes.to_dict()
# Out:
# {'manufacturer': dtype('O'),
#  'model': dtype('O'),
#  'year': dtype('int64'),
#  'mileage': dtype('float64'),
#  'engine': dtype('O'),
#  'transmission': dtype('O'),
#  'drivetrain': dtype('O'),
#  'fuel_type': dtype('O'),
#  'mpg': dtype('O'),
#  'exterior_color': dtype('O'),
#  'interior_color': dtype('O'),
#  'accidents_or_damage': dtype('float64'),
#  'one_owner': dtype('float64'),
#  'personal_use_only': dtype('float64'),
#  'seller_name': dtype('O'),
#  'seller_rating': dtype('float64'),
#  'driver_rating': dtype('float64'),
#  'driver_reviews_num': dtype('float64'),
#  'price_drop': dtype('float64'),
#  'price': dtype('float64')}

# %% [markdown]
# ### <u>1.1 'manufacturer to drivetrain'</u>

# %% [markdown]
# - La columna `manufacturer` la ponemos como tipo **string** porque representa el fabricante del modelo en formato texto.
# - La columna `model` corresponde al modelo del vehículo. Igual que manufacturer, la ponemos como **string**, es una variable categórica.
# - La columna `year` la ponemos como tipo **Int64**, ya que indica el año de fabricación del coche. Es un número entero y no requiere decimales.
# - La columna `mileage` la ponemos como tipo **float64**, ya que los datos del dataset incluyen decimales en los valores de los km.
# - La columna `engine` la ponemos como tipo **string** aunque después la vamos a dividir en varias columnas.
# - La columna `transmission` la ponemos como tipo **string**, ya que nos indica si el coche es manual o automático.
# - La columna `drivetrain` la ponemos como tipo **string**, porque almacena el sistema de tracción del coche.

# %%
df = df.astype({
    'manufacturer': 'string',
    'model': 'string',
    'year': 'Int64',
    'mileage': 'float64',
    'engine': 'string',
    'transmission': 'string',
    'drivetrain': 'string'
})

# %% [markdown]
# ### <u>1.2 'fuel_type to personal_use_only'</u>

# %% [markdown]
# - La columna `fuel_type` la ponemos como tipo **string** porque representa el tipo de combustible de cada vehículo
# - La columna `mpg` la ponemos como **string**, ya que representa un rango entre el minimo y el maximo, aunque luego la vamos a dividir en dos.
# - La columna `exterior_color` la ponemos como tipo **string**, ya que indica el color del exterior. Luego la vamos a eliminar.
# - La columna `interior_color` la ponemos como tipo **string**, ya que indica el color del interior. Luego la vamos a eliminar.
# - La columna `accidents_or_damage` la ponemos como tipo **Int64** ya que es una variable binaria(1 o 0).
# - La columna `one_owner` la ponemos como tipo **Int64**, ya que es una variable binaria(1 o 0).
# - La columna `personal_use_only` la ponemos como tipo **Int64**, ya que es una variable binaria(1 o 0).

# %%
df = df.astype({
    'fuel_type': 'string',
    'mpg': 'string',
    'exterior_color': 'string',
    'interior_color': 'string',
    'accidents_or_damage': 'Int64',
    'one_owner': 'Int64',
    'personal_use_only': 'Int64'
})

# %% [markdown]
# ### <u>1.3 'seller_name to price'</u>

# %% [markdown]
# - La columna `seller_name` la ponemos como tipo **string**, ya que contiene el nombre del vendedor en formato texto.
# - La columna `seller_rating` la ponemos como tipo **float64**, porque representa una valoración numérica con decimales.
# - La columna `driver_rating` la ponemos como tipo **float64**, ya que también es una valoración numérica con decimales.
# - La columna `driver_reviews_num` la ponemos como tipo **Int64**, porque almacena el número de reseñas y es un valor entero, pero queremos permitir valores nulos (`NaN`).
# - La columna `price_drop` la ponemos como tipo **float64**, dado que representa una variación de precio (rebaja) que incluye decimales.
# - La columna `price` la ponemos como tipo **Int64**, porque el precio del vehículo se maneja como valor entero, y así mantenemos compatibilidad con valores nulos si los hubiera.

# %%
df = df.astype({
    'seller_name': 'string',
    'seller_rating': 'float64',
    'driver_rating': 'float64',
    'driver_reviews_num': 'Int64',
    'price_drop': 'float64',
    'price': 'Int64'
})

# %% [markdown]
# ## <u>2. VALORES ERRÓNEOS:</u>

# %%
pd.isnull(df).sum()
# Out:
# manufacturer                0
# model                       0
# year                        0
# mileage                   506
# engine                  15050
# transmission             9904
# drivetrain              21562
# fuel_type               22927
# mpg                    142071
# exterior_color           8859
# interior_color          56975
# accidents_or_damage     24212
# one_owner               31483
# personal_use_only       24852
# seller_name              8593
# seller_rating          213973
# driver_rating           31632
# driver_reviews_num          0
# price_drop             351979
# price                       0
# dtype: int64

# %%
pd.isnull(df[[x for x in df.columns[pd.isnull(df).any()].tolist()]]).sum()
# Out:
# mileage                   506
# engine                  15050
# transmission             9904
# drivetrain              21562
# fuel_type               22927
# mpg                    142071
# exterior_color           8859
# interior_color          56975
# accidents_or_damage     24212
# one_owner               31483
# personal_use_only       24852
# seller_name              8593
# seller_rating          213973
# driver_rating           31632
# price_drop             351979
# dtype: int64

# %%
df[df.isna().any(axis=1)][[x for x in df.columns[pd.isnull(df).any()]]]
# Out:
#          mileage                                             engine  \
# 0        92945.0  1.5L I-4 i-VTEC variable valve control, engine...
# 1        47645.0                        1.5L I4 8V MPFI SOHC Hybrid
# 3       117598.0                        1.5L I4 8V MPFI SOHC Hybrid
# 4       114865.0                        1.5L I4 8V MPFI SOHC Hybrid
# 6        57212.0                        1.5L I4 8V MPFI SOHC Hybrid
# ...          ...                                                ...
# 762082    6302.0                         2.0L I4 16V GDI DOHC Turbo
# 762083   13972.0                               2.0L I4 16V GDI DOHC
# 762087   72900.0       250.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
# 762088   92000.0                        2.5L I5 20V MPFI DOHC Turbo
# 762090  115592.0                        2.5L I5 20V MPFI DOHC Turbo
#
#              transmission         drivetrain fuel_type    mpg  \
# 0               Automatic  Front-wheel Drive  Gasoline  39-38
# 1           Automatic CVT  Front-wheel Drive    Hybrid  39-38
# 3           Automatic CVT  Front-wheel Drive    Hybrid  39-38
# 4           Automatic CVT  Front-wheel Drive    Hybrid  39-38
# 6           Automatic CVT  Front-wheel Drive    Hybrid  39-38
# ...                   ...                ...       ...    ...
# 762082  8-Speed Automatic    All-wheel Drive  Gasoline  25-33
# 762083  8-Speed Automatic    All-wheel Drive  Gasoline  21-32
# 762087                A/T  Front-wheel Drive  Gasoline   <NA>
# 762088  6-Speed Automatic  Front-wheel Drive  Gasoline  21-30
# 762090  6-Speed Automatic    All-wheel Drive  Gasoline  20-29
#
#                  exterior_color interior_color  accidents_or_damage  \
# 0                         Black      Parchment                    0
# 1                          Gray          Ebony                    1
# 3       Polished Metal Metallic           <NA>                    0
# 4                          <NA>          Ebony                    1
# 6                        Silver          Ebony                    0
# ...                         ...            ...                  ...
# 762082     Birch Light Metallic       Charcoal                    0
# 762083                    White           <NA>                    0
# 762087                      Red          Beige                 <NA>
# 762088                Ice White     Soft Beige                    0
# 762090     Savile Gray Metallic      Off-Black                    1
#
#         one_owner  personal_use_only                 seller_name  \
# 0               0                  0                Iconic Coach
# 1               1                  1                  Kars Today
# 3               1                  1            Apple Tree Acura
# 4               0                  1     Herb Connolly Chevrolet
# 6               1                  1               Ohio Car Mart
# ...           ...                ...                         ...
# 762082          1                  0  Scott Volvo Cars Allentown
# 762083          1                  0    Simmons-Rockwell Hyundai
# 762087       <NA>               <NA>                        <NA>
# 762088          0                  1            Dapper Car Sales
# 762090          0                  1         Plymouth Auto Sales
#
#         seller_rating  driver_rating  price_drop
# 0                 NaN            4.4       300.0
# 1                 NaN            4.4         NaN
# 3                 NaN            4.4       675.0
# 4                 3.7            4.4       300.0
# 6                 NaN            4.4         NaN
# ...               ...            ...         ...
# 762082            NaN            4.2         NaN
# 762083            NaN            4.9         NaN
# 762087            NaN            4.5         NaN
# 762088            NaN            4.8       300.0
# 762090            NaN            4.7       501.0
#
# [518591 rows x 15 columns]

# %% [markdown]
# ### <u>2.1 'mileage'</u>
# ##### Hemos imputado los valores faltantes de mileage usando una estrategia escalonada, rellenando primero por manufacturer + model + year y después por medianas de fabricante y globales. Así hemos obtenido un kilometraje coherente con la edad y el tipo de coche, evitando perder datos valiosos.

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)

    df['mileage'] = (
        df.groupby(['manufacturer', 'model', 'year'])['mileage']
          .transform(lambda x: x.fillna(x.median()))
    )

# %% [markdown]
# ##### Estamos rellenando los valores nulos con la mediana teniendo en cuenta las columnas: 'manufacturer','model','year'.

# %%
df['mileage'] = df['mileage'].fillna(df['mileage'].median())

# %% [markdown]
# ##### Tras rellenar los ausentes de 'mileage' con la mediana de 'manufacturer','model','year', nos siguen quedando 20 valores nulos. A estos últimos le hemos rellenado los valores teniendo en cuenta la mediana de 'mileage'.

# %%
df['mileage'].describe()
# Out:
# count    7.620910e+05
# mean     5.577397e+04
# std      4.356073e+04
# min      0.000000e+00
# 25%      2.327400e+04
# 50%      4.559000e+04
# 75%      7.836300e+04
# max      1.119067e+06
# Name: mileage, dtype: float64

# %% [markdown]
# ### <u>2.2 'engine'</u>
# ##### Hemos limpiado la columna engine dividiéndola en tres variables numéricas y categóricas: engine_liters, engine_cylinders y engine_type. Después hemos imputado los valores faltantes de litros y cilindros usando medianas por grupos coherentes (manufacturer + model + year + cylinders), quedando listas para ML

# %%
df['engine_clean'] = df['engine'].str.lower()

# %% [markdown]
# ##### Extraemos la cilindrada (litros)

# %%
def extract_liters(x):
    if pd.isna(x):
        return None
    match = re.search(r'(\d\.\d|\d)\s*l', x)
    if match:
        return float(match.group(1))
    return None

df['engine_liters'] = df['engine_clean'].apply(extract_liters)

# %% [markdown]
# ##### Extraemos el número de cilindridos

# %%
def extract_cylinders(x):
    if pd.isna(x):
        return None
    match = re.search(r'(v|i|l)(\d)', x)
    if match:
        return int(match.group(2))
    return None

df['engine_cylinders'] = df['engine_clean'].apply(extract_cylinders)

# %%
df[df['engine_cylinders'] % 1 != 0]
# Out:
#        manufacturer            model  year   mileage  \
# 0             Acura  ILX Hybrid 1.5L  2013   92945.0
# 7             Acura  ILX Hybrid 1.5L  2014  214000.0
# 14            Acura         NSX Base  2017   15904.0
# 17            Acura            NSX T  1995  320000.0
# 19            Acura         NSX Base  2022    1447.0
# ...             ...              ...   ...       ...
# 762046        Volvo           S60 T5  2013  153673.0
# 762064        Volvo   S60 T5 Premier  2013   50755.0
# 762075        Volvo     S60 Momentum  2020   52559.0
# 762077        Volvo  S60 T5 Momentum  2020   13778.0
# 762087        Volvo           S60 T5  2012   72900.0
#
#                                                    engine  \
# 0       1.5L I-4 i-VTEC variable valve control, engine...
# 7       111.0HP 1.5L 4 Cylinder Engine Gasoline/Mild E...
# 14                  Twin Turbo Gas/Electric V-6 3.5 L/213
# 17                                                   <NA>
# 19      3.5L V-6 port/direct injection, DOHC, VTC vari...
# ...                                                   ...
# 762046  2.5L I-5 DOHC, variable valve control, interco...
# 762064  2.5L I-5 DOHC, variable valve control, interco...
# 762075                                  4 Cylinder Engine
# 762077                                            I-4 cyl
# 762087       250.0HP 2.5L 5 Cylinder Engine Gasoline Fuel
#
#                      transmission         drivetrain fuel_type    mpg  \
# 0                       Automatic  Front-wheel Drive  Gasoline  39-38
# 7                             A/T  Front-wheel Drive    Hybrid   <NA>
# 14                      Automatic    All-wheel Drive    Hybrid  21-22
# 17                    5-Speed M/T   Rear-wheel Drive      <NA>   <NA>
# 19                      Automatic    All-wheel Drive  Gasoline  21-22
# ...                           ...                ...       ...    ...
# 762046                  Automatic  Front-wheel Drive  Gasoline  21-30
# 762064                  Automatic    All-wheel Drive  Gasoline  20-29
# 762075                  Automatic  Front-wheel Drive  Gasoline   <NA>
# 762077  Automatic with Geartronic  Front-wheel Drive  Gasoline   <NA>
# 762087                        A/T  Front-wheel Drive  Gasoline   <NA>
#
#              exterior_color  ... personal_use_only  \
# 0                     Black  ...                 0
# 7                     White  ...              <NA>
# 14               130R White  ...                 1
# 17                      Red  ...              <NA>
# 19            Berlina Black  ...                 1
# ...                     ...  ...               ...
# 762046                 GRAY  ...                 1
# 762064                 GRAY  ...              <NA>
# 762075          Osmium Grey  ...                 1
# 762077  Crystal White Pearl  ...                 1
# 762087                  Red  ...              <NA>
#
#                             seller_name  seller_rating  driver_rating  \
# 0                          Iconic Coach            NaN            4.4
# 7                                  <NA>            NaN            3.7
# 14      Piazza Acura / Honda of Reading            4.7            4.8
# 17                                 <NA>            NaN            5.0
# 19               European Exotic Center            NaN            NaN
# ...                                 ...            ...            ...
# 762046                        Web Autos            NaN            4.7
# 762064     1st International Auto Group            2.6            4.7
# 762075              Stillman Volvo Cars            NaN            4.9
# 762077               Ontario Volvo Cars            NaN            4.9
# 762087                             <NA>            NaN            4.5
#
#        driver_reviews_num  price_drop   price  \
# 0                      12       300.0   13988
# 7                       7         NaN    8500
# 14                     17      2111.0  139876
# 17                      3         NaN   75500
# 19                      0      5000.0  254995
# ...                   ...         ...     ...
# 762046                 62         NaN    8495
# 762064                 62         NaN   15555
# 762075                 24       200.0   26800
# 762077                 24         NaN   29975
# 762087                101         NaN   12500
#
#                                              engine_clean  engine_liters  \
# 0       1.5l i-4 i-vtec variable valve control, engine...            1.5
# 7       111.0hp 1.5l 4 cylinder engine gasoline/mild e...            1.5
# 14                  twin turbo gas/electric v-6 3.5 l/213            3.5
# 17                                                   <NA>            NaN
# 19      3.5l v-6 port/direct injection, dohc, vtc vari...            3.5
# ...                                                   ...            ...
# 762046  2.5l i-5 dohc, variable valve control, interco...            2.5
# 762064  2.5l i-5 dohc, variable valve control, interco...            2.5
# 762075                                  4 cylinder engine            NaN
# 762077                                            i-4 cyl            NaN
# 762087       250.0hp 2.5l 5 cylinder engine gasoline fuel            2.5
#
#         engine_cylinders
# 0                    NaN
# 7                    NaN
# 14                   NaN
# 17                   NaN
# 19                   NaN
# ...                  ...
# 762046               NaN
# 762064               NaN
# 762075               NaN
# 762077               NaN
# 762087               NaN
#
# [135753 rows x 23 columns]

# %%
df = df[df['engine_cylinders'] % 1 == 0]

# %%
df['engine_cylinders'] = df['engine_cylinders'].astype('Int64')

# %% [markdown]
# ##### Extraemos el tipo de motor

# %%
def extract_engine_type(x):
    if pd.isna(x):
        return "unknown"
    if "turbo" in x or "t" in x:
        return "turbo"
    if "super" in x:
        return "supercharged"
    if "electric" in x:
        return "electric"
    if "hybrid" in x:
        return "hybrid"
    return "natural"

df['engine_type'] = df['engine_clean'].apply(extract_engine_type)

# %% [markdown]
# ##### Si engine es electric:
# ##### litros=0;
# ##### cilindros=0
# ##### Si creamos estas 3 columnas para diferenciar realmente entre la cilindrada, el número de cilindros y el tipo de motor podemos eliminar posteriormente 'engine_clean':

# %%
df.drop(columns=['engine_clean'], inplace=True)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)

    df['engine_liters'] = (
        df.groupby(['manufacturer', 'model'])['engine_liters']
          .transform(lambda x: x.fillna(x.median()))
    )

# %% [markdown]
# ##### A los missing values de la nueva columna 'engine_liters', le hemos imputado la mediana teniendo en cuenta las columnas 'manufacturer' y 'model'.

# %%
df['engine_liters'] = df.groupby(['manufacturer'])['engine_liters'] \
                         .transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# #### Como nos siguen quedan valores nulos después de la imputación anterior, le hemos imputado de nuevo la mediana pero ahora teniendo solo en cuenta 'manufacturer'.

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)

    df['engine_cylinders'] = (
        df.groupby(['manufacturer', 'model'])['engine_cylinders']
          .transform(lambda x: x.fillna(x.median()))
    )

# %% [markdown]
# ##### A los missing values de la nueva columna 'engine_cylinders', le hemos imputado la mediana teniendo en cuenta las columnas 'manufacturer' y 'model'.

# %%
df['engine_cylinders'] = df.groupby(['manufacturer'])['engine_cylinders'] \
                            .transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# ##### Como nos siguen quedan valores nulos después de la imputación anterior, le hemos imputado de nuevo la mediana pero ahora teniendo solo en cuenta 'manufacturer'.

# %%
df.drop(columns=['engine'], inplace=True)

# %% [markdown]
# ### <u>2.3 'transmission'</u>
# ##### Hemos clasificado y unificado todos los valores de transmission en automatic, manual y unknown, detectando variantes como A/T, CVT, Dual-Clutch, 8-speed, etc., y hemos eliminado los registros clasificados como “other” tras limpiar la columna correctamente.

# %%
df['transmission_clean'] = df['transmission'].astype(str).str.lower()

def simplify_transmission(x):
    if pd.isna(x) or x.strip() == "":
        return "unknown"
    
    if any(word in x for word in [
        "automatic",          
        "auto ", " auto",     
        "a/t", "at",
        "cvt", 
        "continuously variable", 
        "variable",
        "dct", 
        "dual", 
        "tiptronic", 
        "dsg",
        "shift",
        "8-speed", "8 speed", "8spd",
        "7-speed", "7 speed", "7spd",
        "9-speed", "9 speed", "9spd",
        "10-speed", "10 speed", "10spd"
    ]):
        return "automatic"
    
    if any(word in x for word in [
        "manual",
        "m/t", "mt",
        "man ",
        "5-speed", "5 speed",
        "6-speed", "6 speed",
        "5spd", "6spd"
    ]):
        return "manual"
    
    return "other"

df['transmission_simple'] = df['transmission_clean'].apply(simplify_transmission)
df = df.drop(columns=['transmission_clean'])

# %%
df = df[df['transmission_simple'] != 'other']

# %%
df.drop(columns=['transmission'], inplace=True)

# %% [markdown]
# ### <u>2.4 'drivetrain'</u>
# ##### Hemos normalizado todos los valores de drivetrain en las 4 categorías principales (Front-wheel, Rear-wheel, All-wheel, Four-wheel Drive), y eliminado los registros “unknown” y “other” para quedarnos solo con configuraciones de tracción válidas.

# %%
df['drivetrain'].value_counts()
# Out:
# drivetrain
# Front-wheel Drive                                              210827
# All-wheel Drive                                                178203
# Four-wheel Drive                                               139090
# Rear-wheel Drive                                                79175
# FWD                                                              6263
# AWD                                                              2921
# 4WD                                                              1900
# RWD                                                              1605
# Unknown                                                            63
# Front-Wheel Drive                                                  59
# Four-Wheel Drive with Locking and Limited-Slip Differential        42
# Front-Wheel Drive with Limited-Slip Differential                   38
# All-Wheel Drive with Locking and Limited-Slip Differential         33
# All-Wheel Drive with Locking Differential                          20
# Rear-Wheel Drive                                                   20
# Four-Wheel Drive                                                   16
# Four Wheel Drive                                                   13
# Rear-Wheel Drive with Limited-Slip Differential                    12
# All-Wheel Drive                                                    12
# Four-Wheel Drive with Locking Differential                          6
# Rear Wheel Drive                                                    3
# All Wheel Drive                                                     2
# Front Wheel Drive                                                   2
# 4x4                                                                 1
# Name: count, dtype: Int64

# %%
df['drivetrain_clean'] = df['drivetrain'].astype(str).str.lower()

def simplify_drivetrain(x):
    if pd.isna(x) or x.strip() == "" or x == "nan":
        return "unknown" 

    if any(word in x for word in [
        "front-wheel", "front wheel", "fwd"
    ]):
        return "Front-wheel Drive"

    if any(word in x for word in [
        "rear-wheel", "rear wheel", "rwd"
    ]):
        return "Rear-wheel Drive"
    
    if any(word in x for word in [
        "all-wheel", "all wheel", "awd"
    ]):
        return "All-wheel Drive"
    
    if any(word in x for word in [
        "four-wheel", "four wheel",
        "4wd", "4x4", "4 x 4"
    ]):
        return "Four-wheel Drive"
    
    return "other"

df['drivetrain_simple'] = df['drivetrain_clean'].apply(simplify_drivetrain)
df = df.drop(columns=['drivetrain_clean'])

# %%
df = df[df['drivetrain_simple'] != 'unknown']
df = df[df['drivetrain_simple'] != 'other']

# %%
df['drivetrain_simple'].value_counts()
# Out:
# drivetrain_simple
# Front-wheel Drive    217189
# All-wheel Drive      181191
# Four-wheel Drive     141068
# Rear-wheel Drive      80815
# Name: count, dtype: int64

# %%
df.drop(columns=['drivetrain'], inplace=True)

# %% [markdown]
# ### <u>2.5 'fuel_type'</u>
# ##### Con fuel_type hemos estandarizado todos los valores en 4 categorías limpias (Gasoline, Diesel, Hybrid, Electric),y¡ y hemos eliminado los registros “unknown” y “other” para quedarnos solo con combustibles válidos y consistentes para el modelo.

# %%
df['fuel_clean'] = df['fuel_type'].astype(str).str.lower()

def simplify_fuel(x):
    if pd.isna(x) or x.strip() == "" or x == "nan":
        return "unknown"
    
    if any(word in x for word in [
        "gas", "gasoline", 
        "unleaded", "regular", "petrol"
    ]):
        return "Gasoline"
    
    if any(word in x for word in [
        "diesel", "tdi", "dci", "crdi"
    ]):
        return "Diesel"
    
    if any(word in x for word in [
        "hybrid", "phev", "plug-in"
    ]):
        return "Hybrid"
    
    if any(word in x for word in [
        "electric", "ev", "battery"
    ]):
        return "Electric"
    
    return "other"

df['fuel_simple'] = df['fuel_clean'].apply(simplify_fuel)
df = df.drop(columns=['fuel_clean'])

# %%
df['fuel_simple'].value_counts()
# Out:
# fuel_simple
# Gasoline    543818
# Hybrid       27106
# other        24872
# Diesel       24313
# Electric       154
# Name: count, dtype: int64

# %%
df = df[(df['fuel_simple'] != 'unknown') &
        (df['fuel_simple'] != 'other')]

# %% [markdown]
# ### <u>2.6 'mpg'</u>
# ##### Hemos convertido los rangos de mpg en dos columnas numéricas (mpg_min y mpg_max), corrigiendo incluso los rangos invertidos. Después hemos imputado sus valores faltantes usando medianas por grupos coherentes (manufacturer + model + engine_cylinders).

# %%
def parse_ordered_mpg(x):
    if pd.isna(x):
        return (np.nan, np.nan)
    
    x = str(x).strip().replace("–", "-")
    
    if "-" not in x:
        try:
            v = float(x)
            return (v, v)
        except:
            return (np.nan, np.nan)
    
    nums = re.findall(r'\d+', x)
    
    if len(nums) == 2:
        a, b = float(nums[0]), float(nums[1])
        return (min(a, b), max(a, b)) 
    
    return (np.nan, np.nan)

df[['mpg_min', 'mpg_max']] = df['mpg'].apply(lambda x: pd.Series(parse_ordered_mpg(x)))

# %%
df[['mpg', 'mpg_min', 'mpg_max']].head(20)
# Out:
#       mpg  mpg_min  mpg_max
# 1   39-38     38.0     39.0
# 2   39-38     38.0     39.0
# 3   39-38     38.0     39.0
# 4   39-38     38.0     39.0
# 5   39-38     38.0     39.0
# 6   39-38     38.0     39.0
# 8   39-38     38.0     39.0
# 10  21-22     21.0     22.0
# 11   <NA>      NaN      NaN
# 12  21-22     21.0     22.0
# 13  17-24     17.0     24.0
# 15  17-24     17.0     24.0
# 16   <NA>      NaN      NaN
# 18   <NA>      NaN      NaN
# 20  21-22     21.0     22.0
# 21  21-22     21.0     22.0
# 22  21-22     21.0     22.0
# 23  21-22     21.0     22.0
# 24  21-22     21.0     22.0
# 25  21-22     21.0     22.0

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)

    for col in ['mpg_min', 'mpg_max']:
        df[col] = (
            df.groupby(['manufacturer', 'model', 'engine_cylinders'])[col]
              .transform(lambda x: x.fillna(x.median()))
        )

# %% [markdown]
# ##### A los missing values de las nuevas columnas 'mpg_min y mpg_max', le hemos imputado la mediana teniendo en cuenta las columnas 'manufacturer', 'model' y 'engine_cylinders'.

# %%
for col in ['mpg_min', 'mpg_max']:
    df[col] = df.groupby('engine_cylinders')[col] \
                .transform(lambda x: x.fillna(x.median()))
# Out:
# c:\Users\carro\anaconda3\envs\cunef\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\carro\anaconda3\envs\cunef\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# ##### Como nos siguen quedan valores nulos después de la imputación anterior, le hemos imputado de nuevo la mediana pero ahora teniendo solo en cuenta 'engine_cylinders'

# %%
df['mpg_min'] = df['mpg_min'].fillna(df['mpg_min'].median())
df['mpg_max'] = df['mpg_max'].fillna(df['mpg_max'].median())

# %% [markdown]
# ##### Tras rellenar los ausentes de 'mpg_min' y 'mpg_max' con la mediana de manufacturer','model','engine_cylinders', nos siguen quedando valores nulos, pero muy pocos. A estos últimos le hemos rellenado los valores teniendo en cuenta la mediana en general.

# %%
df = df.drop(columns=['mpg'])

# %% [markdown]
# ### <u>2.7 'exterior_color' y 'interior_color'</u>

# %% [markdown]
# ##### Hemos decidido eliminar las columnas de los colores ya que no tienen un aporte significativo a la hora de predcir el precio, el cual es nuestro objetivo.

# %%
df = df.drop(columns=['exterior_color', 'interior_color'])

# %% [markdown]
# ### <u>2.8 Columnas binarias:</u>

# %% [markdown]
# ##### Para los valores nulos de las columnas: 'accidents_or_damage, one_owner y personal_use_only', al ser columnas binarias, hemos decidido imputar los valores nulos siguiendo la distribución ya existente de la variable. Calculando las distribuciones e imputando después.

# %% [markdown]
# #### 2.8.1 'accidents_or_damage':

# %%
dist = df['accidents_or_damage'].value_counts(normalize=True)
dist
# Out:
# accidents_or_damage
# 0    0.768955
# 1    0.231045
# Name: proportion, dtype: Float64

# %%
df['accidents_or_damage'] = df['accidents_or_damage'].fillna(
    np.random.choice(dist.index, p=dist.values)
)

# %% [markdown]
# #### 2.8.2 'one_owner':

# %%
dist1 = df['one_owner'].value_counts(normalize=True)
dist1
# Out:
# one_owner
# 1    0.565949
# 0    0.434051
# Name: proportion, dtype: Float64

# %%
df['one_owner'] = df['one_owner'].fillna(
    np.random.choice(dist.index, p=dist.values)
)

# %% [markdown]
# #### 2.8.3 'personal_use_only':

# %%
dist2 = df['personal_use_only'].value_counts(normalize=True)
dist2
# Out:
# personal_use_only
# 1    0.65512
# 0    0.34488
# Name: proportion, dtype: Float64

# %%
df['personal_use_only'] = df['personal_use_only'].fillna(
    np.random.choice(dist.index, p=dist.values)
)

# %% [markdown]
# ### <u>2.9 'seller_name'</u>

# %%
df['seller_name'].unique()
# Out:
# <StringArray>
# [                       'Kars Today',      'Weiss Toyota of South County',
#                   'Apple Tree Acura',           'Herb Connolly Chevrolet',
#                         'Kalidy Kia',                     'Ohio Car Mart',
#         'Napleton's Palatine Subaru',         'Stingray Chevrolet Bartow',
#                'D & C Motor Company',                       'Mark Motors',
#  ...
#                 'Performance Toyota',           'Berglund Luxury Roanoke',
#  'Serra Volvo Cars of Traverse City',         'Lehman Volvo Cars of York',
#                 'Junge Cedar Rapids',            'Cherry Hill Volvo Cars',
#   'Premier Volvo Cars Overland Park',             'McGoldrick Automotive',
#              'Motorcars Acura Volvo',                     'Audi Gwinnett']
# Length: 14200, dtype: string

# %%
df['seller_name'].isna().sum()
# Out:
# np.int64(2264)

# %%
n_miss = df['seller_name'].isna().sum()
pct_miss = df['seller_name'].isna().mean() * 100
print(n_miss, pct_miss)
# Out:
# 2264 0.380254320270209

# %% [markdown]
# ##### seller_name presenta un 1% de valores faltantes, probablemente asociados a vendedores que no informan de un nombre comercial o anuncios de particulares, no se eliminan estas filas por tratarse de un porcentaje reducido.

# %%
df['seller_name'] = df['seller_name'].fillna('Unknown_seller')

# %% [markdown]
# ### <u>2.10 'seller_rating'</u>

# %%
df['seller_rating'].unique()
# Out:
# array([nan, 4.3, 3.7, 2.2, 4.6, 3.3, 3.5, 4.5, 4.8, 1.8, 4.7, 4.2, 3.6,
#        3.2, 2.8, 4.9, 2.6, 4.4, 2.4, 5. , 3.9, 2.1, 4.1, 1.5, 3.4, 4. ,
#        3.1, 2.5, 2.9, 3.8, 3. , 2. , 2.3, 1.7, 1.3, 2.7, 1.9, 1.6, 1. ,
#        1.2, 1.4, 1.1])

# %%
df['seller_rating'].isna().sum()
# Out:
# np.int64(146461)

# %%
bins = [1, 2, 3, 4, 5.0001]  
labels = ['1-2', '2-3', '3-4', '4-5']

df['seller_rating_cat'] = pd.cut(
    df['seller_rating'],
    bins=bins,
    labels=labels,
    right=False
)


df['seller_rating_cat'] = df['seller_rating_cat'].astype(object)
df.loc[df['seller_rating'].isna(), 'seller_rating_cat'] = 'sin valoración'


df = df.drop(columns=['seller_rating'])

# %% [markdown]
# ##### La variable seller_rating toma valores entre 1 y 5 y presenta un 28% de valores faltantes, se ha discretizado en rangos (1–2), (2–3), (3–4) y (4–5), creando la variable categórica seller_rating_cat. Las observaciones sin valoración se han agrupado en una categoría adicional sin valoración. Tras esta transformación, la variable numérica original seller_rating se ha eliminado del conjunto de datos, trabajando únicamente con su versión categórica.

# %% [markdown]
# ### <u>2.11 'driver_rating'<u>

# %%
df['driver_rating'].unique()
# Out:
# array([4.4, 3.8, 4.7, 4.8, 4.1, 4.9, 5. , nan, 4. , 4.6, 4.5, 4.3, 4.2,
#        3. , 3.9, 3.7, 3.5, 1. , 3.3, 3.4, 3.2, 2.5, 2.8, 3.6, 3.1, 2.9,
#        2. , 1.3, 2.7, 2.6, 1.9, 2.1, 1.7, 2.2])

# %%
df['driver_rating'].isna().sum()
# Out:
# np.int64(23461)

# %%
bins = [1, 2, 3, 4, 5.0001]
labels = ['1-2', '2-3', '3-4', '4-5']

df['driver_rating_cat'] = pd.cut(
    df['driver_rating'],
    bins=bins,
    labels=labels,
    right=False 
)


df['driver_rating_cat'] = df['driver_rating_cat'].astype(object)
df.loc[df['driver_rating'].isna(), 'driver_rating_cat'] = 'sin valoración'


df = df.drop(columns=['driver_rating'])

# %% [markdown]
# ##### La variable driver_rating toma valores entre 1 y 5 y presenta un 4% de valores faltantes, se ha discretizado en rangos (1–2), (2–3), (3–4) y (4–5), creando la variable categórica driver_rating_cat. Las observaciones sin valoración se han agrupado en una categoría adicional sin valoración. Tras esta transformación, la variable numérica original seller_rating se ha eliminado del conjunto de datos, trabajando únicamente con su versión categórica.

# %% [markdown]
# ### <u>2.12 'drivers_reviews_num'</u>

# %%
df['driver_reviews_num'].unique()
# Out:
# <IntegerArray>
# [ 12,   2,   3,  17,   1,   0,   5,  14,   4,   8,
#  ...
#  771, 149, 383, 334, 170, 314, 241, 391, 289, 189]
# Length: 361, dtype: Int64

# %%
df['driver_reviews_num'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Ningún missing.

# %% [markdown]
# ### <u>2.13 'price'</u>

# %% [markdown]
# ##### Esta columna será nuestro tag/etiqueta.

# %%
df['price'].unique()
# Out:
# <IntegerArray>
# [ 17995,  17000,  14958,  14498,  18000,  15999,  16950, 156890, 109990,
#  139888,
#  ...
#    4197,  36567,  41311,  32864,   8532,  42004,  36328,  41861,   4563,
#   14818]
# Length: 58488, dtype: Int64

# %%
df['price'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Ningún missing.

# %% [markdown]
# ### <u>2.14 'Price_drop'</u>

# %%
df['price_drop'].unique()
# Out:
# array([  nan,  500.,  675., ..., 6382., 4758., 5244.], shape=(5962,))

# %%
df['price_drop'].isna().sum()
# Out:
# np.int64(259136)

# %%
df = df.drop(columns=['price_drop'])

# %% [markdown]
# ##### La variable price_drop refleja la rebaja del precio respecto al precio inicial del anuncio y presenta un 46 % de valores faltantes. Además, los NA no pueden interpretarse de forma consistente (aparecen en vehículos de múltiples años y segmentos) y la variable está asociada a decisiones posteriores a la fijación del precio. Por estos motivos, se ha decidido excluir price_drop del conjunto de variables utilizadas en el modelado.

# %% [markdown]
# ## <u>3. OUTLIERS:</u>

# %% [markdown]
# ### <u>3.1 'mileage'</u>

# %%
to_delete_1 = df[(df['mileage'] > 400000) & (df['year'] > 2015)]
to_delete_2 = df[(df['mileage'] > 400000) & (df['year'] < 1990)]

to_delete = pd.concat([to_delete_1, to_delete_2])

df = df.drop(to_delete.index)

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['mileage'], vert=True)
plt.title('Análisis de outliers del kilometraje')
plt.ylabel('mileage')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# ##### Tras revisar los outliers de mileage, hay que saber interpretarlos. Vemos algunos registros que no son nada fiables. Por ejemplo, un Toyota Camry LE del 2020 con 769.938 km.También vemos un Porsche 359 A de 1959 con un 1.000.0000 de km aprox. Hemos decidido eliminar los registros cuyo 'year' sea superior al 2017 y tengan más de 400.000 km. Es muy complicado hacerle tantos km en tan pocos años, ni siquiera un taxista o un camionero llega a esos números. También vamos a eliminar los coches cuyo 'year' sea inferior a 1990 y tengan más de 400.000 km ya que los coches de los 60-70-80 no tenían motores capaces de ser tan duraderos. En la década de los 90, se comienzan a fabricar coches con motores potentes, de los cuales algunos han llegado posteriormente al millón de km con un mantenimiento adecuado.

# %% [markdown]
# ### <u>3.2 'engine_liters'<u>

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['engine_liters'], vert=True)
plt.title('Análisis de outliers de la cilindrada del motor')
plt.ylabel('engine_liters')
plt.show()

# %%
df = df[(df['engine_liters'] >= 1.0) & (df['engine_liters'] <= 7.5)]

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['engine_liters'], vert=True)
plt.title('Análisis de outliers de la cilindrada del motor')
plt.ylabel('engine_liters')
plt.xticks([])
plt.show()

# %% [markdown]
# ##### Para la detección de los outliers de 'engine_liters' hemos seguido la lógica del sector automovilístico y hemos eliminado los registros que se encontraban fuera del umbral 1L – 7.5L. En EEUU no existen motores de combustión menores de 1 litro salvo casos muy excepcionales al igual que los que superan los 7.5L, por eso nos quedamos con los registros que se encuentren de este umbral.

# %% [markdown]
# ### <u>3.3 'drivers_reviews_num'<u>

# %%
df[['driver_reviews_num']].boxplot()
plt.title('Análisis de outliers de numero de visitas')
plt.show()

# %%
umbral_alto_reviews = df['driver_reviews_num'].quantile(0.995)
df = df[df['driver_reviews_num'] <= umbral_alto_reviews]

# %%
df[['driver_reviews_num']].boxplot()
plt.title('Análisis de outliers de numero de visitas')
plt.show()

# %% [markdown]
# ##### En cuanto a los outliers de drivers_review_num, entendiendo que pudiera haber algún valor erróneo extremadamente lejano del global de datos se ha decidido eliminar un porcentaje diminuto de la cola superior, aunque pudiera haber algún anuncio de coche extramadamente popular, no se entiende se llegue a casos extremos.

# %% [markdown]
# ### <u>3.4 'price'</u>

# %% [markdown]
# ##### Nuestro tag/etiqueta.

# %%
df[['price']].boxplot()
plt.title('Análisis de outliers de precios')
plt.show()

# %%
print(df['price'].max())
print(df['price'].mean())
print(df['price'].min())
# Out:
# 1000000000
# 37371.96207913069
# 1

# %%
df[df['price'] == df['price'].max()]
# Out:
#        manufacturer            model  year   mileage fuel_type  \
# 108142    Chevrolet        Cobalt LT  2009   85185.0  Gasoline
# 188113        Dodge  Durango Citadel  2018  113207.0  Gasoline
# 188260        Dodge  Durango Citadel  2018  113207.0  Gasoline
#
#         accidents_or_damage  one_owner  personal_use_only  \
# 108142                    0          1                  1
# 188113                    0          1                  1
# 188260                    0          1                  1
#
#                                         seller_name  driver_reviews_num  ...  \
# 108142  Rothrock Nissan, Chrysler, Dodge, Jeep, RAM                  90  ...
# 188113  Rothrock Nissan, Chrysler, Dodge, Jeep, RAM                 146  ...
# 188260  Rothrock Nissan, Chrysler, Dodge, Jeep, RAM                 146  ...
#
#         engine_liters  engine_cylinders  engine_type transmission_simple  \
# 108142            2.2                 4      natural           automatic
# 188113            3.6                 6      natural           automatic
# 188260            3.6                 6      natural           automatic
#
#         drivetrain_simple fuel_simple mpg_min  mpg_max  seller_rating_cat  \
# 108142  Front-wheel Drive    Gasoline    24.0     32.0                4-5
# 188113    All-wheel Drive    Gasoline    18.0     25.0                4-5
# 188260    All-wheel Drive    Gasoline    18.0     25.0                4-5
#
#        driver_rating_cat
# 108142               4-5
# 188113               4-5
# 188260               4-5
#
# [3 rows x 21 columns]

# %%
df = df[df['price'] != df['price'].max()]

# %%
df[['price']].boxplot()
plt.title('Análisis de outliers de precios')
plt.show()

# %%
print(df['price'].max())
print(df['price'].mean())
print(df['price'].min())
# Out:
# 3490000
# 32307.005151253707
# 1

# %%
df[df['price'] == df['price'].max()]
# Out:
#        manufacturer                     model  year  mileage fuel_type  \
# 636956          RAM  ProMaster 3500 High Roof  2017  83000.0  Gasoline
#
#         accidents_or_damage  one_owner  personal_use_only     seller_name  \
# 636956                    0          0                  0  Unknown_seller
#
#         driver_reviews_num  ...  engine_liters  engine_cylinders  engine_type  \
# 636956                   0  ...            3.6                 6      natural
#
#        transmission_simple  drivetrain_simple fuel_simple mpg_min  mpg_max  \
# 636956           automatic  Front-wheel Drive    Gasoline     0.0      0.0
#
#         seller_rating_cat driver_rating_cat
# 636956     sin valoración    sin valoración
#
# [1 rows x 21 columns]

# %%
df = df[df['price'] != df['price'].max()]

# %%
df[df['price'] == df['price'].max()]
# Out:
#        manufacturer       model  year  mileage fuel_type  accidents_or_damage  \
# 613085      Porsche  Carrera GT  2005    780.0  Gasoline                    0
#
#         one_owner  personal_use_only                        seller_name  \
# 613085          0                  0  Hubbard Auto Center of Scottsdale
#
#         driver_reviews_num  ...  engine_liters  engine_cylinders  engine_type  \
# 613085                   5  ...            5.7                 1      natural
#
#        transmission_simple drivetrain_simple fuel_simple mpg_min  mpg_max  \
# 613085              manual  Rear-wheel Drive    Gasoline    10.0     16.0
#
#         seller_rating_cat driver_rating_cat
# 613085     sin valoración               4-5
#
# [1 rows x 21 columns]

# %%
df = df[df['price'] != df['price'].max()]

# %%
df[['price']].boxplot()
plt.title('Análisis de outliers de precios')
plt.show()

# %%
df.nlargest(20, 'price')
# Out:
#          manufacturer                  model  year   mileage fuel_type  \
# 609009        Porsche  918 Spyder Base (PDK)  2015    2622.0    Hybrid
# 613080        Porsche             Carrera GT  2004    2361.0  Gasoline
# 49078             BMW                 750 iL  1996  121043.0  Gasoline
# 613084        Porsche             Carrera GT  2005    9610.0  Gasoline
# 213659           Ford     GT EDITION VIN 002  2018       9.0  Gasoline
# 613079        Porsche   Carrera GT Base (M6)  2004    4376.0  Gasoline
# 613081        Porsche             Carrera GT  2005   12996.0  Gasoline
# 613083        Porsche             Carrera GT  2005    5052.0  Gasoline
# 613082        Porsche   Carrera GT Base (M6)  2005   10982.0  Gasoline
# 613086        Porsche   Carrera GT Base (M6)  2005   11750.0  Gasoline
# 540908  Mercedes-Benz            SLR McLaren  2009     650.0  Gasoline
# 91190        Cadillac                    DTS  2006  158021.0  Gasoline
# 613087        Porsche             Carrera GT  2005    8342.0  Gasoline
# 540909  Mercedes-Benz            SLR McLaren  2006     461.0  Gasoline
# 517360  Mercedes-Benz               AMG GT C  2021      38.0  Gasoline
# 213660           Ford                GT Base  2006    6492.0  Gasoline
# 541508  Mercedes-Benz          AMG G 63 Base  2021    1450.0  Gasoline
# 213664           Ford                GT Base  2005    2804.0  Gasoline
# 540906  Mercedes-Benz            SLR McLaren  2006    3302.0  Gasoline
# 213645           Ford                GT Base  2006     261.0  Gasoline
#
#         accidents_or_damage  one_owner  personal_use_only  \
# 609009                    0          0                  1
# 613080                    0          0                  1
# 49078                     0          0                  1
# 613084                    0          0                  0
# 213659                    0          1                  1
# 613079                    0          0                  1
# 613081                    0          0                  1
# 613083                    0          0                  1
# 613082                    0          0                  1
# 613086                    0          0                  1
# 540908                    0          0                  1
# 91190                     0          0                  1
# 613087                    1          0                  1
# 540909                    0          0                  1
# 517360                    0          1                  1
# 213660                    0          0                  1
# 541508                    0          0                  1
# 213664                    0          0                  0
# 540906                    0          0                  1
# 213645                    0          0                  1
#
#                                seller_name  driver_reviews_num  ...  \
# 609009            Graham Rahal Performance                   5  ...
# 613080                Kearns Motor Car Co.                   2  ...
# 49078             Celebrity Cars Las Vegas                   2  ...
# 613084                              Ilusso                   5  ...
# 213659                       HGreg.com Lux                   0  ...
# 613079               Porsche North Houston                   2  ...
# 613081               Porsche North Olmsted                   5  ...
# 613083                               ZWECK                   5  ...
# 613082                    Miller Motorcars                   5  ...
# 613086                      Merit Partners                   5  ...
# 540908                           Car Geeks                   2  ...
# 91190        Greve Chrysler Dodge Jeep RAM                  79  ...
# 613087                  Starfire Auto Inc.                   5  ...
# 540909                Fusion Luxury Motors                   6  ...
# 517360              Prestige Annapolis LLC                   0  ...
# 213660                    Jordan Motorcars                  13  ...
# 541508                       HGreg.com Lux                   0  ...
# 213664  Crown Dodge Chrysler Jeep Ram - CA                   1  ...
# 540906                Fusion Luxury Motors                   6  ...
# 213645                   Motorcar Classics                  13  ...
#
#         engine_liters  engine_cylinders   engine_type transmission_simple  \
# 609009            4.6                 8        hybrid           automatic
# 613080            5.7                 1       natural              manual
# 49078             5.4                 1       natural           automatic
# 613084            5.7                 1       natural              manual
# 213659            3.5                 6       natural           automatic
# 613079            5.7                 1       natural              manual
# 613081            5.7                 1       natural              manual
# 613083            5.7                 1       natural              manual
# 613082            5.7                 1       natural              manual
# 613086            5.7                 1       natural              manual
# 540908            5.4                 8  supercharged           automatic
# 91190             4.6                 8       natural           automatic
# 613087            5.7                 1       natural              manual
# 540909            5.4                 8  supercharged           automatic
# 517360            4.0                 8         turbo           automatic
# 213660            5.4                 8  supercharged              manual
# 541508            4.0                 8         turbo           automatic
# 213664            5.4                 8  supercharged              manual
# 540906            5.4                 8  supercharged           automatic
# 213645            5.4                 8  supercharged              manual
#
#         drivetrain_simple fuel_simple mpg_min  mpg_max  seller_rating_cat  \
# 609009    All-wheel Drive      Hybrid    20.0     24.0     sin valoración
# 613080   Rear-wheel Drive    Gasoline    10.0     16.0                4-5
# 49078   Front-wheel Drive    Gasoline    15.0     20.0                4-5
# 613084   Rear-wheel Drive    Gasoline    10.0     16.0     sin valoración
# 213659   Rear-wheel Drive    Gasoline    18.0     25.0                4-5
# 613079   Rear-wheel Drive    Gasoline    10.0     16.0                4-5
# 613081   Rear-wheel Drive    Gasoline    10.0     16.0                4-5
# 613083   Rear-wheel Drive    Gasoline    10.0     16.0     sin valoración
# 613082   Rear-wheel Drive    Gasoline    10.0     16.0     sin valoración
# 613086   Rear-wheel Drive    Gasoline    10.0     16.0                4-5
# 540908   Rear-wheel Drive    Gasoline    12.0     16.0                2-3
# 91190   Front-wheel Drive    Gasoline    15.0     23.0                3-4
# 613087   Rear-wheel Drive    Gasoline    10.0     16.0                3-4
# 540909   Rear-wheel Drive    Gasoline    13.0     17.0     sin valoración
# 517360   Rear-wheel Drive    Gasoline    20.0     20.0     sin valoración
# 213660   Rear-wheel Drive    Gasoline    13.0     21.0     sin valoración
# 541508    All-wheel Drive    Gasoline    13.0     16.0                4-5
# 213664   Rear-wheel Drive    Gasoline    13.0     21.0                2-3
# 540906   Rear-wheel Drive    Gasoline    13.0     17.0     sin valoración
# 213645   Rear-wheel Drive    Gasoline    13.0     21.0                3-4
#
#        driver_rating_cat
# 609009               3-4
# 613080               4-5
# 49078                4-5
# 613084               4-5
# 213659    sin valoración
# 613079               4-5
# 613081               4-5
# 613083               4-5
# 613082               4-5
# 613086               4-5
# 540908               4-5
# 91190                4-5
# 613087               4-5
# 540909               4-5
# 517360    sin valoración
# 213660               4-5
# 541508    sin valoración
# 213664               4-5
# 540906               4-5
# 213645               4-5
#
# [20 rows x 21 columns]

# %%
umbral_alto = df['price'].quantile(0.999)
print(umbral_alto)

df = df[df['price'] <= umbral_alto]
# Out:
# 203900.0

# %%
df[['price']].boxplot()
plt.title('Análisis de outliers de precios')
plt.show()

# %%
print(df['price'].max())
print(df['price'].mean())
print(df['price'].min())
# Out:
# 203900
# 32040.349348476397
# 1

# %%
df[df['price'] == df['price'].min()]
# Out:
#        manufacturer            model  year   mileage fuel_type  \
# 5658          Acura    TLX V6 A-Spec  2018   49603.0  Gasoline
# 13850          Audi  A4 2.0T Premium  2014   98881.0  Gasoline
# 735177   Volkswagen            Jetta  2007  133964.0  Gasoline
#
#         accidents_or_damage  one_owner  personal_use_only        seller_name  \
# 5658                      1          0                  1   Luxury Auto Mall
# 13850                     0          0                  0   Luxury Auto Mall
# 735177                    1          0                  1  Fred Anderson Kia
#
#         driver_reviews_num  ...  engine_liters  engine_cylinders  engine_type  \
# 5658                    83  ...            3.5                 6      natural
# 13850                   59  ...            2.0                 4        turbo
# 735177                  72  ...            2.5                 5      natural
#
#        transmission_simple  drivetrain_simple fuel_simple mpg_min  mpg_max  \
# 5658             automatic  Front-wheel Drive    Gasoline    20.0     30.0
# 13850            automatic  Front-wheel Drive    Gasoline    24.0     32.0
# 735177              manual  Front-wheel Drive    Gasoline    22.0     30.0
#
#         seller_rating_cat driver_rating_cat
# 5658                  1-2               4-5
# 13850                 1-2               4-5
# 735177                4-5               4-5
#
# [3 rows x 21 columns]

# %%
df.nsmallest(20, 'price')
# Out:
#        manufacturer               model  year   mileage fuel_type  \
# 5658          Acura       TLX V6 A-Spec  2018   49603.0  Gasoline
# 13850          Audi     A4 2.0T Premium  2014   98881.0  Gasoline
# 735177   Volkswagen               Jetta  2007  133964.0  Gasoline
# 66049         Buick     Enclave Premium  2017  115869.0  Gasoline
# 162360     Chrysler  Pacifica Touring L  2020   55240.0  Gasoline
# 165200        Dodge    Grand Caravan GT  2019   72860.0  Gasoline
# 165324        Dodge    Grand Caravan GT  2019   72860.0  Gasoline
# 566508       Nissan           Maxima SE  2001  157000.0  Gasoline
# 165031        Dodge          Caravan SE  1997  201611.0  Gasoline
# 760485        Volvo              V70 T5  1998  193695.0  Gasoline
# 567062       Nissan         Cube 1.8 SL  2009  121505.0  Gasoline
# 247974         Ford              Ranger  1989  200028.0  Gasoline
# 250581         Ford           Taurus SE  2002  214207.0  Gasoline
# 424110          Kia          Sorento LX  2007  251072.0  Gasoline
# 176129        Dodge          Avenger SE  2008  162222.0  Gasoline
# 99988     Chevrolet       Uplander Base  2005  148164.0  Gasoline
# 555745   Mitsubishi              Lancer  2006  255000.0  Gasoline
# 127081    Chevrolet         Cavalier LS  2002  153610.0  Gasoline
# 170656        Dodge            Ram 1500  2002  305138.0  Gasoline
# 185691        Dodge         Durango SLT  2005  230327.0  Gasoline
#
#         accidents_or_damage  one_owner  personal_use_only  \
# 5658                      1          0                  1
# 13850                     0          0                  0
# 735177                    1          0                  1
# 66049                     1          0                  1
# 162360                    0          1                  0
# 165200                    1          1                  0
# 165324                    1          1                  0
# 566508                    0          0                  1
# 165031                    0          0                  0
# 760485                    1          0                  1
# 567062                    0          1                  1
# 247974                    0          0                  1
# 250581                    1          0                  1
# 424110                    1          0                  0
# 176129                    1          0                  0
# 99988                     1          0                  1
# 555745                    1          0                  1
# 127081                    1          0                  1
# 170656                    1          0                  1
# 185691                    0          0                  1
#
#                                          seller_name  driver_reviews_num  ...  \
# 5658                                Luxury Auto Mall                  83  ...
# 13850                               Luxury Auto Mall                  59  ...
# 735177                             Fred Anderson Kia                  72  ...
# 66049                                Lions Pre-Owned                 137  ...
# 162360                               Lions Pre-Owned                  64  ...
# 165200                               Lions Pre-Owned                  70  ...
# 165324                               Lions Pre-Owned                  70  ...
# 566508  Patriot Chrysler Dodge Jeep Ram of McAlester                  22  ...
# 165031                        East Coast Auto Source                   2  ...
# 760485                        East Coast Auto Source                  25  ...
# 567062                   Marketplace Chevrolet Buick                  44  ...
# 247974                                  Ruddell Auto                   7  ...
# 250581                        East Coast Auto Source                  48  ...
# 424110                              Dan Deery Toyota                  29  ...
# 176129                         Western Avenue Nissan                  83  ...
# 99988                          Western Avenue Nissan                  21  ...
# 555745                      Benji Auto Sales Orlando                  15  ...
# 127081                        East Coast Auto Source                  32  ...
# 170656                     Allstar Auto Services LLC                  39  ...
# 185691                                Kia of Bradley                  49  ...
#
#         engine_liters  engine_cylinders  engine_type transmission_simple  \
# 5658              3.5                 6      natural           automatic
# 13850             2.0                 4        turbo           automatic
# 735177            2.5                 5      natural              manual
# 66049             3.6                 6        turbo           automatic
# 162360            3.6                 6        turbo           automatic
# 165200            3.6                 6        turbo           automatic
# 165324            3.6                 6        turbo           automatic
# 566508            3.0                 6      natural           automatic
# 165031            3.0                 6      natural           automatic
# 760485            2.4                 5        turbo           automatic
# 567062            1.8                 4      natural           automatic
# 247974            2.3                 4      natural              manual
# 250581            3.0                 6      natural           automatic
# 424110            3.8                 6      natural           automatic
# 176129            2.4                 4      natural           automatic
# 99988             3.5                 6      natural           automatic
# 555745            2.0                 4      natural           automatic
# 127081            2.2                 4      natural           automatic
# 170656            3.7                 6      natural              manual
# 185691            5.7                 8      natural           automatic
#
#         drivetrain_simple fuel_simple mpg_min  mpg_max  seller_rating_cat  \
# 5658    Front-wheel Drive    Gasoline    20.0     30.0                1-2
# 13850   Front-wheel Drive    Gasoline    24.0     32.0                1-2
# 735177  Front-wheel Drive    Gasoline    22.0     30.0                4-5
# 66049   Front-wheel Drive    Gasoline    15.0     22.0     sin valoración
# 162360  Front-wheel Drive    Gasoline    19.0     28.0     sin valoración
# 165200  Front-wheel Drive    Gasoline    17.0     25.0     sin valoración
# 165324  Front-wheel Drive    Gasoline    17.0     25.0     sin valoración
# 566508  Front-wheel Drive    Gasoline    19.0     26.0                3-4
# 165031  Front-wheel Drive    Gasoline    18.0     25.0                1-2
# 760485   Four-wheel Drive    Gasoline    20.0     28.0                1-2
# 567062  Front-wheel Drive    Gasoline    28.0     30.0                4-5
# 247974   Rear-wheel Drive    Gasoline    20.0     24.0                3-4
# 250581  Front-wheel Drive    Gasoline    20.0     28.0                1-2
# 424110   Four-wheel Drive    Gasoline    17.0     22.0                4-5
# 176129  Front-wheel Drive    Gasoline    21.0     30.0                1-2
# 99988   Front-wheel Drive    Gasoline    18.0     24.0                1-2
# 555745  Front-wheel Drive    Gasoline    28.0     35.0                1-2
# 127081  Front-wheel Drive    Gasoline    25.0     34.0                1-2
# 170656   Rear-wheel Drive    Gasoline    15.0     20.0                4-5
# 185691   Four-wheel Drive    Gasoline    14.0     18.0                2-3
#
#        driver_rating_cat
# 5658                 4-5
# 13850                4-5
# 735177               4-5
# 66049                4-5
# 162360               4-5
# 165200               4-5
# 165324               4-5
# 566508               4-5
# 165031               4-5
# 760485               4-5
# 567062               4-5
# 247974               4-5
# 250581               4-5
# 424110               4-5
# 176129               4-5
# 99988                3-4
# 555745               4-5
# 127081               4-5
# 170656               4-5
# 185691               4-5
#
# [20 rows x 21 columns]

# %%
umbral_bajo = df['price'].quantile(0.001) 
print(umbral_bajo)

df = df[df['price'] >= umbral_bajo]
# Out:
# 3353.4449999999997

# %%
df[['price']].boxplot()
plt.title('Análisis de outliers de precios')
plt.show()

# %%
df.nsmallest(20, 'price')
# Out:
#          manufacturer                model  year   mileage fuel_type  \
# 140801      Chevrolet         Tracker Base  2003  135033.0  Gasoline
# 281723            GMC            Envoy SLE  2006  194781.0  Gasoline
# 428790            Kia     Amanti Base (A5)  2005  139531.0  Gasoline
# 26089            Audi       A6 3.2 quattro  2006  186648.0  Gasoline
# 251036           Ford       Taurus Limited  2014  239101.0  Gasoline
# 268143           Ford  Transit Connect XLT  2012  197332.0  Gasoline
# 521515  Mercedes-Benz         E-Class E320  2005  108704.0  Gasoline
# 564844         Nissan            Maxima SE  2007  175715.0  Gasoline
# 701007         Toyota                 ECHO  2000  139357.0  Gasoline
# 70443           Buick          Lucerne CXL  2006  114000.0  Gasoline
# 169310          Dodge          Magnum Base  2008  171000.0  Gasoline
# 329653          Honda              CR-V SE  2001  219512.0  Gasoline
# 706231         Toyota            Avalon XL  1996  228989.0  Gasoline
# 741128     Volkswagen        Rabbit 4-Door  2007  137400.0  Gasoline
# 754971          Volvo                  S70  2000  120520.0  Gasoline
# 279204            GMC         Envoy XL SLE  2006  187276.0  Gasoline
# 251463           Ford            Taurus SE  1999  177055.0  Gasoline
# 70865           Buick      LeSabre Limited  2003  215531.0  Gasoline
# 76393           Buick       Century Custom  2002  206226.0  Gasoline
# 77094           Buick    Park Avenue Ultra  1997  222404.0  Gasoline
#
#         accidents_or_damage  one_owner  personal_use_only  \
# 140801                    0          0                  1
# 281723                    1          0                  1
# 428790                    1          0                  0
# 26089                     0          0                  1
# 251036                    0          0                  0
# 268143                    1          1                  1
# 521515                    1          0                  1
# 564844                    1          0                  0
# 701007                    0          0                  1
# 70443                     1          0                  1
# 169310                    0          0                  0
# 329653                    0          0                  1
# 706231                    0          0                  1
# 741128                    1          1                  0
# 754971                    1          0                  1
# 279204                    0          0                  0
# 251463                    0          0                  0
# 70865                     1          0                  1
# 76393                     1          0                  1
# 77094                     1          0                  1
#
#                                         seller_name  driver_reviews_num  ...  \
# 140801                  Derrow-Shirkey Ford Lincoln                  26  ...
# 281723                          Andy Mohr Buick GMC                  33  ...
# 428790                          Illinois Auto Sales                  25  ...
# 26089                        East Coast Auto Source                  42  ...
# 251036                       East Coast Auto Source                  92  ...
# 268143                       East Coast Auto Source                  39  ...
# 521515                       East Coast Auto Source                  54  ...
# 564844                            Lindner Chevrolet                  74  ...
# 701007                                      Autopik                  30  ...
# 70443                     South Texas American Auto                  51  ...
# 169310                               Unknown_seller                  16  ...
# 329653  Champion Chrysler Jeep Dodge Ram of Lansing                  43  ...
# 706231         Dan Cummins Chevrolet Buick of Paris                  15  ...
# 741128                            Import Autos INC.                  50  ...
# 754971                                 Uzdcarz Inc.                  31  ...
# 279204                      Corwin Public Wholesale                  19  ...
# 251463                      Corwin Public Wholesale                  31  ...
# 70865                                Korz Auto Farm                  35  ...
# 76393                                Korz Auto Farm                  22  ...
# 77094                         Brinkman Brothers Inc                  11  ...
#
#         engine_liters  engine_cylinders   engine_type transmission_simple  \
# 140801            2.0                 4       natural           automatic
# 281723            4.2                 6       natural           automatic
# 428790            3.5                 6       natural           automatic
# 26089             3.1                 6       natural           automatic
# 251036            3.5                 6       natural           automatic
# 268143            2.0                 4       natural           automatic
# 521515            3.2                 6       natural           automatic
# 564844            3.5                 6       natural           automatic
# 701007            1.5                 4       natural           automatic
# 70443             3.8                 6       natural           automatic
# 169310            2.7                 6       natural           automatic
# 329653            2.0                 4       natural           automatic
# 706231            3.0                 6       natural           automatic
# 741128            2.5                 5       natural           automatic
# 754971            2.4                 5       natural              manual
# 279204            4.2                 6       natural           automatic
# 251463            3.0                 6       natural           automatic
# 70865             3.8                 6       natural           automatic
# 76393             3.1                 6       natural           automatic
# 77094             3.8                 6  supercharged           automatic
#
#         drivetrain_simple fuel_simple mpg_min  mpg_max  seller_rating_cat  \
# 140801   Four-wheel Drive    Gasoline    24.0     31.0                2-3
# 281723   Four-wheel Drive    Gasoline    15.0     21.0                4-5
# 428790  Front-wheel Drive    Gasoline    17.0     25.0                1-2
# 26089     All-wheel Drive    Gasoline    19.0     27.0                1-2
# 251036  Front-wheel Drive    Gasoline    19.0     29.0                1-2
# 268143  Front-wheel Drive    Gasoline    21.0     27.0                1-2
# 521515   Rear-wheel Drive    Gasoline    20.0     28.0                1-2
# 564844  Front-wheel Drive    Gasoline    21.0     28.0                4-5
# 701007  Front-wheel Drive    Gasoline    31.0     38.0     sin valoración
# 70443   Front-wheel Drive    Gasoline    19.0     28.0     sin valoración
# 169310   Rear-wheel Drive    Gasoline    21.0     28.0     sin valoración
# 329653   Four-wheel Drive    Gasoline    22.0     25.0                2-3
# 706231  Front-wheel Drive    Gasoline    20.0     29.0                4-5
# 741128  Front-wheel Drive    Gasoline    22.0     30.0     sin valoración
# 754971  Front-wheel Drive    Gasoline    21.0     29.0     sin valoración
# 279204   Four-wheel Drive    Gasoline    14.0     20.0                4-5
# 251463  Front-wheel Drive    Gasoline    18.0     27.0                4-5
# 70865   Front-wheel Drive    Gasoline    20.0     29.0                3-4
# 76393   Front-wheel Drive    Gasoline    20.0     29.0                3-4
# 77094   Front-wheel Drive    Gasoline    18.0     27.0     sin valoración
#
#        driver_rating_cat
# 140801               4-5
# 281723               4-5
# 428790               4-5
# 26089                4-5
# 251036               4-5
# 268143               3-4
# 521515               4-5
# 564844               4-5
# 701007               4-5
# 70443                4-5
# 169310               4-5
# 329653               4-5
# 706231               4-5
# 741128               4-5
# 754971               4-5
# 279204               4-5
# 251463               4-5
# 70865                4-5
# 76393                4-5
# 77094                4-5
#
# [20 rows x 21 columns]

# %% [markdown]
# ##### La variable price presenta algunos valores extremadamente bajos y altos que no son representativos del mercado típico de coches de segunda mano y pueden distorsionar el análisis y los modelos.Para reducir su impacto, eliminamos solo los casos más extremos usando percentiles:

# %% [markdown]
# ##### - Umbral inferior: percentil 0.1% de price.
# ##### - Umbral superior: percentil 99.9% de price.

# %% [markdown]
# ##### Nos quedamos únicamente con las observaciones cuyo precio está entre ambos valores.

# %%
df
# Out:
#        manufacturer            model  year   mileage fuel_type  \
# 1             Acura  ILX Hybrid 1.5L  2013   47645.0    Hybrid
# 2             Acura  ILX Hybrid 1.5L  2013   53422.0    Hybrid
# 3             Acura  ILX Hybrid 1.5L  2013  117598.0    Hybrid
# 4             Acura  ILX Hybrid 1.5L  2013  114865.0    Hybrid
# 5             Acura  ILX Hybrid 1.5L  2013   62042.0    Hybrid
# ...             ...              ...   ...       ...       ...
# 762085        Volvo           S60 T5  2020   26781.0  Gasoline
# 762086        Volvo  S60 B5 Momentum  2022   22877.0  Gasoline
# 762088        Volvo           S60 T5  2014   92000.0  Gasoline
# 762089        Volvo  S60 T5 Platinum  2013  132000.0  Gasoline
# 762090        Volvo   S60 T5 Premier  2015  115592.0  Gasoline
#
#         accidents_or_damage  one_owner  personal_use_only  \
# 1                         1          1                  1
# 2                         0          1                  1
# 3                         0          1                  1
# 4                         1          0                  1
# 5                         0          0                  1
# ...                     ...        ...                ...
# 762085                    1          1                  1
# 762086                    0          1                  0
# 762088                    0          0                  1
# 762089                    1          0                  0
# 762090                    1          0                  1
#
#                          seller_name  driver_reviews_num  ...  engine_liters  \
# 1                         Kars Today                  12  ...            1.5
# 2       Weiss Toyota of South County                  12  ...            1.5
# 3                   Apple Tree Acura                  12  ...            1.5
# 4            Herb Connolly Chevrolet                  12  ...            1.5
# 5                         Kalidy Kia                  12  ...            1.5
# ...                              ...                 ...  ...            ...
# 762085        Jenkins Volvo of Ocala                  24  ...            2.0
# 762086            Volvo Cars Danbury                   2  ...            2.0
# 762088              Dapper Car Sales                  36  ...            2.5
# 762089        Legend Auto Sales Inc.                  62  ...            2.5
# 762090           Plymouth Auto Sales                  51  ...            2.5
#
#         engine_cylinders  engine_type transmission_simple  drivetrain_simple  \
# 1                      4       hybrid           automatic  Front-wheel Drive
# 2                      4       hybrid           automatic  Front-wheel Drive
# 3                      4       hybrid           automatic  Front-wheel Drive
# 4                      4       hybrid           automatic  Front-wheel Drive
# 5                      4       hybrid           automatic  Front-wheel Drive
# ...                  ...          ...                 ...                ...
# 762085                 4        turbo           automatic  Front-wheel Drive
# 762086                 4        turbo           automatic    All-wheel Drive
# 762088                 5        turbo           automatic  Front-wheel Drive
# 762089                 5        turbo           automatic    All-wheel Drive
# 762090                 5        turbo           automatic    All-wheel Drive
#
#        fuel_simple mpg_min  mpg_max  seller_rating_cat driver_rating_cat
# 1           Hybrid    38.0     39.0     sin valoración               4-5
# 2           Hybrid    38.0     39.0                4-5               4-5
# 3           Hybrid    38.0     39.0     sin valoración               4-5
# 4           Hybrid    38.0     39.0                3-4               4-5
# 5           Hybrid    38.0     39.0                2-3               4-5
# ...            ...     ...      ...                ...               ...
# 762085    Gasoline    23.0     34.0                4-5               4-5
# 762086    Gasoline    25.0     33.0                4-5               4-5
# 762088    Gasoline    21.0     30.0     sin valoración               4-5
# 762089    Gasoline    20.0     29.0                4-5               4-5
# 762090    Gasoline    20.0     29.0     sin valoración               4-5
#
# [591098 rows x 21 columns]

# %% [markdown]
# ## <u>4. GRÁFICOS DE DISTRIBUCIONES:</u>

# %% [markdown]
# ### <u>4.1 Distribución de los fabricantes (top 10 fabricantes más comunes)</u>:

# %%
top_manufacturers = df['manufacturer'].value_counts().head(10)

plt.figure(figsize=(10,6))
plt.bar(top_manufacturers.index, top_manufacturers.values)
plt.xticks(rotation=45)
plt.title("Top 10 fabricantes más comunes")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### <u>4.2 Distribución del kilometraje</u>:

# %%
bins = [0, 50000, 100000, 150000, 200000, 250000, 300000, 400000]
labels = ['0-50km','50-100km','100-150km','150-200km','200-250km','250-300km','300-400km']

df['mileage_bin'] = pd.cut(df['mileage'], bins=bins, labels=labels)

plt.figure(figsize=(8,5))
sns.countplot(x='mileage_bin', data=df, order=labels)
plt.title("Distribución de coches por rangos de kilometraje")
plt.xlabel("")
plt.ylabel("Número de coches")
plt.show()

df.drop(columns=['mileage_bin'], inplace=True)

# %% [markdown]
# ### <u>4.3 Distribución de la cilidrada del motor</u>:

# %%
plt.figure(figsize=(8, 5))
df["engine_liters"].dropna().hist(bins=30)
plt.xlabel("Cilindrada del motor (L)")
plt.ylabel("Frecuencia")
plt.title("Distribución de la cilindrada del motor")
plt.show()

# %% [markdown]
# ### <u>4.5 Distribución del número de cilindros</u>:

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='engine_cylinders', data=df)
plt.title("Distribución del número de cilindros")
plt.xlabel("Número de cilindros")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### <u>4.6 Distribución del tipo de motor</u>:

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='engine_type', data=df, order=df['engine_type'].value_counts().index)
plt.title("Distribución del tipo de motor")
plt.xlabel("")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### <u>4.7 Distribución de la transmisión</u>:

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='transmission_simple', data=df, order=df['transmission_simple'].value_counts().index)
plt.title("Distribución del tipo de transmisión")
plt.xlabel("")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### <u>4.8 Distribución del sistema de tracción</u>:

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='drivetrain_simple', data=df, order=df['drivetrain_simple'].value_counts().index)
plt.title("Distribución del sistema de tracción")
plt.xlabel("")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### <u>4.9 Distribución del tipo de combustible</u>:

# %% [markdown]
# ##### fuel_type contiene un montón de clases muy raras, mezclas, formatos inconsistentes y variantes casi duplicadas, por tanto agrupamos las clases que no tienen casi valores en 'otros'

# %%
counts = df['fuel_type'].value_counts()
top = counts[counts > 5000] 
other = counts[counts <= 5000].sum()

top["Otros"] = other

top.plot(kind='bar', figsize=(8,4))
plt.title("Distribución de tipos de combustible (agrupada por frecuencia)")
plt.xlabel("Tipo de combustible")
plt.ylabel("Número de vehículos")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <u>4.10 Distribución de millas por galón</u>

# %%
df['mpg_min'].plot(kind='hist', bins=30, figsize=(8,4))
plt.title("Distribución de MPG (minimo del rango)")
plt.xlabel("MPG min")
plt.xlim(0, 60)
plt.tight_layout()
plt.show()

# %%
df['mpg_max'].plot(kind='hist', bins=30, figsize=(8,4))
plt.title("Distribución de MPG (maximo del rango)")
plt.xlabel("MPG max")
plt.xlim(0, 60)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <u>4.11 Distribución de accidentes o daños</u>

# %%
df['accidents_or_damage'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(5,5),
    labels=['No', 'Sí']
)
plt.title("Distribución: Accidents or Damage")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### <u>4.12 Distribución si solo tiene un dueño</u>

# %%
df['one_owner'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(5,5),
    labels=['Más de un dueño', 'Un solo dueño']
)
plt.title("Distribución: One Owner")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### <u>4.13 Distribución del uso personal</u>

# %%
df['personal_use_only'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(5,5),
    labels=['Uso mixto', 'Uso personal'] 
)
plt.title("Distribución: Personal Use Only")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### <u>4.14 Distribución del precio</u>:

# %%
plt.figure(figsize=(8, 5))
df["price"].dropna().hist(bins=30)
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.title("Distribución del precio de los vehículos")
plt.show()

# %% [markdown]
# ### <u>4.15 Precio medio por vendedor (top 10 vendedores con más coches)</u>:

# %%
top_sellers = (
    df["seller_name"]
    .value_counts()
    .head(10)
    .index
)

price_by_seller = (
    df[df["seller_name"].isin(top_sellers)]
    .groupby("seller_name")["price"]
    .mean()
    .sort_values()
)

plt.figure(figsize=(10, 5))
price_by_seller.plot(kind="bar")
plt.ylabel("Precio medio")
plt.title("Precio medio por vendedor (top 10)")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <u>4.16 Número de reseñas de conductores</u>:

# %%
plt.figure(figsize=(8, 5))
df["driver_reviews_num"].dropna().hist(bins=30)
plt.xlabel("Número de reseñas")
plt.ylabel("Frecuencia")
plt.title("Distribución del número de reseñas de conductores/usuarios")
plt.show()

# %% [markdown]
# ## <u>5. GUARDÁMOS DATASET LIMPIO:</u>

# %%
df_clean = df

df_clean.to_csv('../data/processed/clean_cars.csv', index=False)
