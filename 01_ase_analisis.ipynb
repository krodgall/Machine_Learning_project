# %% [markdown]
# Jaime tiene mareos

# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')

# %%
df
# Out:
#        manufacturer            model  year   mileage  \
# 0             Acura  ILX Hybrid 1.5L  2013   92945.0
# 1             Acura  ILX Hybrid 1.5L  2013   47645.0
# 2             Acura  ILX Hybrid 1.5L  2013   53422.0
# 3             Acura  ILX Hybrid 1.5L  2013  117598.0
# 4             Acura  ILX Hybrid 1.5L  2013  114865.0
# ...             ...              ...   ...       ...
# 762086        Volvo  S60 B5 Momentum  2022   22877.0
# 762087        Volvo           S60 T5  2012   72900.0
# 762088        Volvo           S60 T5  2014   92000.0
# 762089        Volvo  S60 T5 Platinum  2013  132000.0
# 762090        Volvo   S60 T5 Premier  2015  115592.0
#
#                                                    engine       transmission  \
# 0       1.5L I-4 i-VTEC variable valve control, engine...          Automatic
# 1                             1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# 2                             1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# ...

# %%
#Análisis Exploratorio

# %%
df['manufacturer'].value_counts()
# Out:
# manufacturer
# Ford             79526
# Toyota           59535
# Chevrolet        56043
# Nissan           48529
# Jeep             41665
# Mercedes-Benz    40824
# Honda            37612
# BMW              37570
# Kia              35063
# GMC              29563
# Dodge            25250
# Subaru           24767
# Volkswagen       24620
# Hyundai          22203
# Lexus            21301
# RAM              19364
# Audi             17863
# Cadillac         17794
# Mazda            15485
# Buick            14624
# Chrysler         12647
# INFINITI         12289
# Land Rover       12272
# Porsche          11461
# Lincoln          10608
# Volvo            10029
# Acura             8489
# Tesla             5883
# Mitsubishi        5743
# Jaguar            3469
# Name: count, dtype: int64

# %%
#Pasamos todos los valores de 'engine' a minúsculas.
df['engine_clean'] = df['engine'].str.lower()

# %%
#Extraemos la cilindrada (litros)
import re

def extract_liters(x):
    if pd.isna(x):
        return None
    match = re.search(r'(\d\.\d|\d)\s*l', x)
    if match:
        return float(match.group(1))
    return None

df['engine_liters'] = df['engine_clean'].apply(extract_liters)

# %%
#Extraemos el número de cilindridos
def extract_cylinders(x):
    if pd.isna(x):
        return None
    match = re.search(r'(v|i|l)(\d)', x)
    if match:
        return int(match.group(2))
    return None

df['engine_cylinders'] = df['engine_clean'].apply(extract_cylinders)

# %%
#Extraer tipo de motor
def extract_engine_type(x):
    if pd.isna(x):
        return "unknown"
    if "turbo" in x or "t" in x:
        return "turbo"
    if "super" in x:
        return "supercharged"
    if "electric" in x:
        return "electric"
    if "hybrid" in x:
        return "hybrid"
    return "natural"

df['engine_type'] = df['engine_clean'].apply(extract_engine_type)

# %%
#Si engine es electric: litros=0; cilindros=0
#Si creamos estas 3 columnas para diferenciar realmente entre la cilindrada, el número de cilindros y el tipo de motor podemos eliminar posteriormente 'engine_clean':
#df.drop(columns=['engine_clean'], inplace=True)

# %%
df['year'].min(), df['year'].max()
# Out:
# (1915, 2024)

# %% [markdown]
# MILEAGE

# %%
#El kilometraje del coche es muy importante. Para los valores ausentes, podemos imputar la mediana por grupo teniendo en cuenta manufacturer + model + year

# %% [markdown]
# ENGINE

# %%
#Rellenar con una categoría “unknown” ANTES de aplicar las funciones de limpieza.

# %% [markdown]
# TRANSMISSION

# %% [markdown]
# Aquí vamos a dividir esta columna en 3 categorías

# %%
# df['transmission_clean'] = df['transmission'].astype(str).str.lower()

# def simplify_transmission(x):
#     if pd.isna(x):
#         return "unknown"
    
#     # AUTOMÁTICAS
#     if any(word in x for word in [
#         "auto", "cvt", "dct", "dual", "tiptronic", "dsg", "shift"
#     ]):
#         return "automatic"
    
#     # MANUALES
#     if "manual" in x or "man " in x or " 5mt" in x or " 6mt" in x:
#         return "manual"
    
#     return "other"

# df['transmission'] = df['transmission_clean'].apply(simplify_transmission)
# df = df.drop(columns=['transmission_clean'])

# %%
df
# Out:
#        manufacturer            model  year   mileage  \
# 0             Acura  ILX Hybrid 1.5L  2013   92945.0
# 1             Acura  ILX Hybrid 1.5L  2013   47645.0
# 2             Acura  ILX Hybrid 1.5L  2013   53422.0
# 3             Acura  ILX Hybrid 1.5L  2013  117598.0
# 4             Acura  ILX Hybrid 1.5L  2013  114865.0
# ...             ...              ...   ...       ...
# 762086        Volvo  S60 B5 Momentum  2022   22877.0
# 762087        Volvo           S60 T5  2012   72900.0
# 762088        Volvo           S60 T5  2014   92000.0
# 762089        Volvo  S60 T5 Platinum  2013  132000.0
# 762090        Volvo   S60 T5 Premier  2015  115592.0
#
#                                                    engine       transmission  \
# 0       1.5L I-4 i-VTEC variable valve control, engine...          Automatic
# 1                             1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# 2                             1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# ...
